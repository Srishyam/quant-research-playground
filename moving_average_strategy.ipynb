# %% [markdown]
# # Install stuff

# %% [markdown]
# !pip install yfinance

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 31.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt
# Download Apple's daily stock price for the last 2 years
data = yf.download("AAPL", start="2023-01-01", end="2025-01-01")
data['Close'].plot(title="AAPL Closing Price")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# Download ticker's daily stock price for past 2 years
ticker = "SPY"
data = yf.download(ticker, start="2020-01-01", end="2025-05-01")

# Compute moving averages
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA50'] = data['Close'].rolling(window=50).mean()

# Plot the data
plt.figure(figsize=(12,6))
plt.plot(data['Close'], label='Close Price')
plt.plot(data['MA20'], label='20-Day MA')
plt.plot(data['MA50'], label='50-Day MA')
plt.title(f"{ticker} Closing Price with Moving Averages")
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
